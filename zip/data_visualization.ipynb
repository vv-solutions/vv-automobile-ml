# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/polo_data.csv',sep=';')
df['price'] = df['price'].str.replace(r'\D','',regex=True)
df['price'] = df['price'].astype('int64')
print(len(df))
df.head()
# Out:
# 807
#     price  model_year      km         reg fuel_type  fuel_economy  \
# 0  154900        2018  147000  2018-02-28    Benzin          21.7
# 1  339900        2022    8000  2022-06-03    Benzin          17.5
# 2  209900        2018   73000  2018-05-25    Benzin          21.7
# 3    7900        2002  280000  2002-10-16    Benzin          15.5
# 4  249800        2018   72000  2018-08-15    Benzin          16.9
#
#    horse_power gear_type  zip_code
# 0           95         A      7700
# 1          207         A      4700
# 2           95         A      3520
# 3           75         M      6000
# 4          200         A      6760

# %% [markdown]
# <h2> Geographical

# %%
df['east']= df['zip_code'] < 4999
df
# Out:
#       price  model_year      km         reg fuel_type  fuel_economy  \
# 0    154900        2018  147000  2018-02-28    Benzin          21.7
# 1    339900        2022    8000  2022-06-03    Benzin          17.5
# 2    209900        2018   73000  2018-05-25    Benzin          21.7
# 3      7900        2002  280000  2002-10-16    Benzin          15.5
# 4    249800        2018   72000  2018-08-15    Benzin          16.9
# ..      ...         ...     ...         ...       ...           ...
# 802  189900        2018   88000  2018-05-30    Benzin          21.3
# 803  249900        2019   27000  2019-07-10    Benzin          18.0
# 804  192000        2016   42000  2015-11-01    Benzin          21.3
# 805   73500        2010  161000  2010-11-01    Diesel          29.4
# 806   28000        2000  296000  2000-08-30    Benzin          15.9
#
#      horse_power gear_type  zip_code   east
# 0             95         A      7700  False
# 1            207         A      4700   True
# 2             95         A      3520   True
# 3             75         M      6000  False
# 4            200         A      6760  False
# ..           ...       ...       ...    ...
# 802          115         A      6500  False
# 803          200         A      6270  False
# 804          150         A      5700  False
# 805           75         M      2100   True
# 806           60         M      4100   True
#
# [807 rows x 10 columns]

# %%
east = (df['east'] == True)
west = (df['east'] == False)

east_price = df[east]['price']
west_price = df[west]['price']

print(sum(east_price)/len(east_price))
print(sum(west_price)/len(west_price))
# Out:
# 170425.27575757576
# 170176.11111111112

# %%
regions = ['East','West']
avg_prices = [
    sum(east_price)/len(east_price),
    sum(west_price)/len(west_price)
]


plt.bar(regions,avg_prices)
# Out:
# <BarContainer object of 2 artists>

# %%
import pandas as pd
import re
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns

# %% [markdown]
# <h2> data clean-up

# %%
df = pd.read_csv('../data/polo_data.csv',sep=';')
print(len(df))
df.head()
# Out:
# 807
#          price  model_year      km         reg fuel_type  fuel_economy  \
# 0  154.900 kr.        2018  147000  2018-02-28    Benzin          21.7
# 1  339.900 kr.        2022    8000  2022-06-03    Benzin          17.5
# 2  209.900 kr.        2018   73000  2018-05-25    Benzin          21.7
# 3    7.900 kr.        2002  280000  2002-10-16    Benzin          15.5
# 4  249.800 kr.        2018   72000  2018-08-15    Benzin          16.9
#
#    horse_power gear_type  zip_code
# 0           95         A      7700
# 1          207         A      4700
# 2           95         A      3520
# 3           75         M      6000
# 4          200         A      6760

# %%
#Cleans price and first regestration
df['price'] = df['price'].str.replace(r'\D','',regex=True)
df['price'] = df['price'].astype('int64')
df['reg'] = df['reg'].str.split('-').str[0]
df['reg'] = df['reg'].astype('int64')
df
# Out:
#       price  model_year      km   reg fuel_type  fuel_economy  horse_power  \
# 0    154900        2018  147000  2018    Benzin          21.7           95
# 1    339900        2022    8000  2022    Benzin          17.5          207
# 2    209900        2018   73000  2018    Benzin          21.7           95
# 3      7900        2002  280000  2002    Benzin          15.5           75
# 4    249800        2018   72000  2018    Benzin          16.9          200
# ..      ...         ...     ...   ...       ...           ...          ...
# 802  189900        2018   88000  2018    Benzin          21.3          115
# 803  249900        2019   27000  2019    Benzin          18.0          200
# 804  192000        2016   42000  2015    Benzin          21.3          150
# 805   73500        2010  161000  2010    Diesel          29.4           75
# 806   28000        2000  296000  2000    Benzin          15.9           60
#
#     gear_type  zip_code
# 0           A      7700
# 1           A      4700
# 2           A      3520
# 3           M      6000
# 4           A      6760
# ..        ...       ...
# 802         A      6500
# 803         A      6270
# 804         A      5700
# 805         M      2100
# 806         M      4100
#
# [807 rows x 9 columns]

# %%
#converts categorical variable into dummy/indicator variables
df = pd.get_dummies(df, columns = ['gear_type','fuel_type'])
df
# Out:
#       price  model_year      km   reg  fuel_economy  horse_power  zip_code  \
# 0    154900        2018  147000  2018          21.7           95      7700
# 1    339900        2022    8000  2022          17.5          207      4700
# 2    209900        2018   73000  2018          21.7           95      3520
# 3      7900        2002  280000  2002          15.5           75      6000
# 4    249800        2018   72000  2018          16.9          200      6760
# ..      ...         ...     ...   ...           ...          ...       ...
# 802  189900        2018   88000  2018          21.3          115      6500
# 803  249900        2019   27000  2019          18.0          200      6270
# 804  192000        2016   42000  2015          21.3          150      5700
# 805   73500        2010  161000  2010          29.4           75      2100
# 806   28000        2000  296000  2000          15.9           60      4100
#
#      gear_type_A  gear_type_M  fuel_type_Benzin  fuel_type_Diesel
# 0              1            0                 1                 0
# 1              1            0                 1                 0
# 2              1            0                 1                 0
# 3              0            1                 1                 0
# 4              1            0                 1                 0
# ..           ...          ...               ...               ...
# 802            1            0                 1                 0
# 803            1            0                 1                 0
# 804            1            0                 1                 0
# 805            0            1                 0                 1
# 806            0            1                 1                 0
#
# [807 rows x 11 columns]

# %%
#selects target and features
X = df[['model_year', 'km','reg','fuel_economy','horse_power','gear_type_A','gear_type_M','fuel_type_Benzin','fuel_type_Diesel']]
y = df['price']

# %%
#Test train split of data, 33% test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=42)

# %% [markdown]
# <h2> Linear Regression model

# %%
#fits model
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)

#degree of linear correlation between data and target
print(f'Regression score: {regr.score(X_train,y_train)}')
# Out:
# Regression score: 0.9303087693764053

# %%
#Test of 5 cars
print(f'Car 1: Predicted price: {regr.predict(X_test[0:1])[0].round(2)}kr - actual price: {y_test[0:1].values[0]}kr')
print(f'Car 2: Predicted price: {regr.predict(X_test[1:2])[0].round(2)}kr - actual price: {y_test[1:2].values[0]}kr')
print(f'Car 3: Predicted price: {regr.predict(X_test[2:3])[0].round(2)}kr - actual price: {y_test[2:3].values[0]}kr')
print(f'Car 4: Predicted price: {regr.predict(X_test[3:4])[0].round(2)}kr - actual price: {y_test[3:4].values[0]}kr')
print(f'Car 5: Predicted price: {regr.predict(X_test[4:5])[0].round(2)}kr - actual price: {y_test[4:5].values[0]}kr')
# Out:
# Car 1: Predicted price: 231241.99kr - actual price: 209900kr
# Car 2: Predicted price: 96638.2kr - actual price: 89900kr
# Car 3: Predicted price: 201036.0kr - actual price: 204800kr
# Car 4: Predicted price: 167062.77kr - actual price: 179900kr
# Car 5: Predicted price: 206589.84kr - actual price: 224900kr

# %%
#Method to get prediction score
def get_prediction_score(target,pred_target):
    score_list = []
    for num1,num2 in zip(target,pred_target):
        if num1 > num2:
            score_list.append(num2/num1*100)
        elif num2 > num1:
            score_list.append(num1/num2*100)
        else:
            score_list.append(100)
    return sum(score_list) / len(score_list)

# %%
#Test of prediction score
y_pred = regr.predict(X_test)
get_prediction_score(y_test,y_pred)
# Out:
# 90.54031072885509

# %% [markdown]
# <h2> Decision tree regressor

# %%
#Fit and model score
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
#predictions = model.predict(X_test)
dtr.score(X_test, y_test)
# Out:
# 0.9635457867962697

# %%
#Test of 5 cars
print(f'Car 1: Predicted price: {dtr.predict(X_test[0:1])[0].round(2)}kr - actual price: {y_test[0:1].values[0]}kr')
print(f'Car 2: Predicted price: {dtr.predict(X_test[1:2])[0].round(2)}kr - actual price: {y_test[1:2].values[0]}kr')
print(f'Car 3: Predicted price: {dtr.predict(X_test[2:3])[0].round(2)}kr - actual price: {y_test[2:3].values[0]}kr')
print(f'Car 4: Predicted price: {dtr.predict(X_test[3:4])[0].round(2)}kr - actual price: {y_test[3:4].values[0]}kr')
print(f'Car 5: Predicted price: {dtr.predict(X_test[4:5])[0].round(2)}kr - actual price: {y_test[4:5].values[0]}kr')
# Out:
# Car 1: Predicted price: 209900.0kr - actual price: 209900kr
# Car 2: Predicted price: 91450.0kr - actual price: 89900kr
# Car 3: Predicted price: 194900.0kr - actual price: 204800kr
# Car 4: Predicted price: 174900.0kr - actual price: 179900kr
# Car 5: Predicted price: 224900.0kr - actual price: 224900kr

# %%
#Test of prediction score
y_pred = dtr.predict(X_test)
get_prediction_score(y_test,y_pred)
# Out:
# 93.25456485037797

# %% [markdown]
# <h1>data visualization

# %%
#Heatmap to show correlation between target and feautres
sns.heatmap(df.corr(), annot=True)
df.corr()
# Out:
#                      price  model_year        km       reg  fuel_economy  \
# price             1.000000    0.843693 -0.793588  0.848053     -0.250847
# model_year        0.843693    1.000000 -0.781710  0.993804      0.081444
# km               -0.793588   -0.781710  1.000000 -0.778249      0.184165
# reg               0.848053    0.993804 -0.778249  1.000000      0.074177
# fuel_economy     -0.250847    0.081444  0.184165  0.074177      1.000000
# horse_power       0.647486    0.342536 -0.263981  0.353775     -0.468194
# zip_code         -0.010592    0.006658  0.077816  0.004258      0.070471
# gear_type_A       0.640793    0.443782 -0.371435  0.448752     -0.222410
# gear_type_M      -0.640793   -0.443782  0.371435 -0.448752      0.222410
# fuel_type_Benzin  0.387777    0.320292 -0.531271  0.312913     -0.692789
# fuel_type_Diesel -0.387777   -0.320292  0.531271 -0.312913      0.692789
#
#                   horse_power  zip_code  gear_type_A  gear_type_M  \
# price                0.647486 -0.010592     0.640793    -0.640793
# model_year           0.342536  0.006658     0.443782    -0.443782
# km                  -0.263981  0.077816    -0.371435     0.371435
# reg                  0.353775  0.004258     0.448752    -0.448752
# fuel_economy        -0.468194  0.070471    -0.222410     0.222410
# horse_power          1.000000  0.017993     0.490528    -0.490528
# zip_code             0.017993  1.000000    -0.026635     0.026635
# gear_type_A          0.490528 -0.026635     1.000000    -1.000000
# gear_type_M         -0.490528  0.026635    -1.000000     1.000000
# fuel_type_Benzin     0.243075 -0.101947     0.179953    -0.179953
# fuel_type_Diesel    -0.243075  0.101947    -0.179953     0.179953
#
#                   fuel_type_Benzin  fuel_type_Diesel
# price                     0.387777         -0.387777
# model_year                0.320292         -0.320292
# km                       -0.531271          0.531271
# reg                       0.312913         -0.312913
# fuel_economy             -0.692789          0.692789
# horse_power               0.243075         -0.243075
# zip_code                 -0.101947          0.101947
# gear_type_A               0.179953         -0.179953
# gear_type_M              -0.179953          0.179953
# fuel_type_Benzin          1.000000         -1.000000
# fuel_type_Diesel         -1.000000          1.000000

# %%
#Plots
sns.pairplot(df[['price','km','model_year','reg']])

# %%
#regplot with price and model year
sns.regplot(x=df['price'], y=df['km'], ci=None)
# Out:
# <AxesSubplot:xlabel='price', ylabel='km'>

# %%
#map of the descision tree
fig = plt.figure(figsize=(15,25))
_= tree.plot_tree(dtr, feature_names=X.columns, filled=True)
